# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
covid19 = pd.read_csv('covid19_Confirmed_dataset.csv')
covid19.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...     4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0   ...        1092     1176     1279     1351
# 1        0        0        0   ...         609      634      663      678
# 2        0        0        0   ...        2811     2910     3007     3127
# 3        0        0        0   ...         717      723      723      731
# 4        0        0        0   ...          24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# # Removing un-necessary columns

# %%
covid19.drop(['Lat','Long'],axis = 1,inplace = True)

# %%
covid19.head(15)
# Out:
#                   Province/State       Country/Region  1/22/20  1/23/20  \
# 0                            NaN          Afghanistan        0        0
# 1                            NaN              Albania        0        0
# 2                            NaN              Algeria        0        0
# 3                            NaN              Andorra        0        0
# 4                            NaN               Angola        0        0
# 5                            NaN  Antigua and Barbuda        0        0
# 6                            NaN            Argentina        0        0
# 7                            NaN              Armenia        0        0
# 8   Australian Capital Territory            Australia        0        0
# 9                New South Wales            Australia        0        0
# 10            Northern Territory            Australia        0        0
# 11                    Queensland            Australia        0        0
# ...

# %% [markdown]
# # Aggrigating the covid dataset and grouping it by 'Country/Region'

# %% [markdown]
# As we can see for Australia different data row are present for different Province/State hence we need to add all the cases for each Province/State for every country.

# %%
corona = covid19.groupby('Country/Region').sum()

# %%
corona.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20   ...     4/21/20  \
# ...

# %% [markdown]
# # Now we need to add a new column max_infection_rate

# %% [markdown]
# we need to get max infection for each country for every 24 hours and then add this as a column in the corona dataframe

# %%
countries = list(corona.index)
infection_rate = []
for country in countries:
    infection_rate.append(corona.loc[country].diff().max())
corona['max_infection_rate'] = infection_rate

# %%
corona.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20         ...          4/22/20  \
# Country/Region                                    ...
# Afghanistan           0        0        0         ...             1176
# Albania               0        0        0         ...              634
# Algeria               0        0        0         ...             2910
# Andorra               0        0        0         ...              723
# Angola                0        0        0         ...               25
# ...

# %% [markdown]
# Now as we have the max_infection_rate for each countries, we do not require the rest positive cases on each dates. Hence we will drop all except the max_infection_rate

# %%
covid = pd.DataFrame(corona['max_infection_rate'])
covid.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# Now importing World happiness report dataset

# %%
whr = pd.read_csv('worldwide_happiness_report.csv')
whr.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# Now removing columns that are not required for this analysis

# %%
whr.drop(['Overall rank','Score','Generosity','Perceptions of corruption'],axis=1,inplace = True)
whr.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# Now we are required to join the two dataframes and to ease this step we set the 'Country or region' as index

# %%
whr.set_index(['Country or region'],inplace = True)
whr.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# now before joining the two dataframe it is agood practice to check the shape of both the dataframes

# %%
covid.shape
# Out:
# (187, 1)

# %% [markdown]
# covid - 187 countries and 1 max_infection_rate

# %%
whr.shape
# Out:
# (156, 4)

# %% [markdown]
# whr - 156 countries and 4 cols(GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices)

# %%
final_df = covid.join(whr,how = 'inner')
final_df.head(10)
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# Australia                 497.0           1.372           1.548
# Austria                  1321.0           1.376           1.475
# Azerbaijan                105.0           1.043           1.147
# Bahrain                   301.0           1.362           1.368
# Bangladesh                641.0           0.562           0.928
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %% [markdown]
# # Now to get the co-relation of each feature with other we use .corr() function

# %%
final_df.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
import seaborn as sns

# %% [markdown]
# Now to plot every co-relation

# %%
sns.pairplot(final_df.corr())

# %%
sns.pairplot(final_df)

# %%
plt.figure(figsize=(10,4))
sns.regplot(final_df['GDP per capita'],final_df['max_infection_rate'])

# %% [markdown]
# # OUTPUT

# %% [markdown]
# By doing some data preprocessing and exploratory data analysis on the given dataset I came to a conclusion that developed countries are more prone to get infected by corona virus.
